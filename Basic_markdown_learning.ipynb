# %% [markdown]
# 1. Switching to Markdown Cell
#
# Click on a cell.
#
# Press Esc then M to convert it to a Markdown cell.
#
# Or use the dropdown menu that says "Code" → select Markdown.

# %% [markdown]
# . Basic Markdown Syntax
# Headings
# # Heading 1
# ## Heading 2
# ### Heading 3

# %% [markdown]
# Bold & Italic
#
# **bold text**
#
# *italic text*
#
# ***bold and italic***

# %% [markdown]
# ## Lists
#
# ### Unordered list:
#
# - Item 1
# - Item 2
#   - Subitem

# %% [markdown]
# ### Ordered list:
#
# 1. First
# 2. Second
#    1. Subitem

# %% [markdown]
# ## Links
# [OpenAI](https://www.openai.com)

# %% [markdown]
# ## Images
# ![Alt text](https://example.com/image.png)

# %% [markdown]
# ## Code
#
# ### Inline code:
#
# `print("Hello")`
#
# ### Code block (with syntax highlighting):
#
# ```python
# def add(a, b):
#     return a + b

# %% [markdown]
# #### **Horizontal Line**
# ```markdown
# ---

# %% [markdown]
# #### Blockquote
# > This is a quote.
# >> This is a quote.
# >>> This is a quote.

# %% [markdown]
# 3. Keyboard Shortcuts
#
# Run cell: Shift + Enter
#
# Convert to Markdown: Esc → M
#
# Convert to Code: Esc → Y

# %% [markdown]
# | Arrow          | Symbol |
# |----------------|--------|
# | Right arrow    | →      |
# | Left arrow     | ←      |
# | Up arrow       | ↑      |
# | Down arrow     | ↓      |
# | Double right   | ⇒      |
# | Double left    | ⇐      |
# | Bidirectional  | ↔      |
